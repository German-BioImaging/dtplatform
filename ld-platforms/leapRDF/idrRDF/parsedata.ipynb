# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in ./venv/lib/python3.8/site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.1.2; however, version 22.1 is available.
# You should consider upgrading via the '/Users/andra/PycharmProjects/leapRDF/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install rdflib
# Out:
# Requirement already satisfied: rdflib in ./venv/lib/python3.8/site-packages (6.1.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.8/site-packages (from rdflib) (3.0.9)
# Requirement already satisfied: isodate in ./venv/lib/python3.8/site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from rdflib) (57.0.0)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from isodate->rdflib) (1.16.0)
# WARNING: You are using pip version 21.1.2; however, version 22.1 is available.
# You should consider upgrading via the '/Users/andra/PycharmProjects/leapRDF/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install wikidataintegrator
# Out:
# Requirement already satisfied: wikidataintegrator in ./venv/lib/python3.8/site-packages (0.9.22)
# Requirement already satisfied: mwoauth in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (0.3.7)
# Requirement already satisfied: pyshex in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (0.8.1)
# Requirement already satisfied: tqdm in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (4.64.0)
# Requirement already satisfied: shexer in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (2.0.1)
# Requirement already satisfied: jsonasobj in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (1.3.1)
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (2.27.1)
# Requirement already satisfied: simplejson in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (3.17.6)
# Requirement already satisfied: python-dateutil in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (2.8.2)
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (1.4.2)
# Requirement already satisfied: backoff in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (2.0.1)
# Requirement already satisfied: oauthlib in ./venv/lib/python3.8/site-packages (from wikidataintegrator) (3.2.0)
# Requirement already satisfied: PyJWT<2.0.0,>=1.0.1 in ./venv/lib/python3.8/site-packages (from mwoauth->wikidataintegrator) (1.7.1)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.8/site-packages (from mwoauth->wikidataintegrator) (1.3.1)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from mwoauth->wikidataintegrator) (1.16.0)
# Requirement already satisfied: numpy>=1.18.5 in ./venv/lib/python3.8/site-packages (from pandas->wikidataintegrator) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.8/site-packages (from pandas->wikidataintegrator) (2022.1)
# Requirement already satisfied: pyshexc==0.9.1 in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (0.9.1)
# Requirement already satisfied: chardet in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (4.0.0)
# Requirement already satisfied: urllib3 in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (1.26.9)
# Requirement already satisfied: sparqlwrapper>=1.8.5 in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (2.0.0)
# Requirement already satisfied: cfgraph>=0.2.1 in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (0.2.1)
# Requirement already satisfied: sparqlslurper>=0.5.1 in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (0.5.1)
# Requirement already satisfied: rdflib-shim in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (1.0.3)
# Requirement already satisfied: shexjsg>=0.8.2 in ./venv/lib/python3.8/site-packages (from pyshex->wikidataintegrator) (0.8.2)
# Requirement already satisfied: antlr4-python3-runtime~=4.9.3 in ./venv/lib/python3.8/site-packages (from pyshexc==0.9.1->pyshex->wikidataintegrator) (4.9.3)
# Requirement already satisfied: pyjsg>=0.11.10 in ./venv/lib/python3.8/site-packages (from pyshexc==0.9.1->pyshex->wikidataintegrator) (0.11.10)
# Requirement already satisfied: rdflib>=0.4.2 in ./venv/lib/python3.8/site-packages (from cfgraph>=0.2.1->pyshex->wikidataintegrator) (6.1.1)
# Requirement already satisfied: pyparsing in ./venv/lib/python3.8/site-packages (from rdflib>=0.4.2->cfgraph>=0.2.1->pyshex->wikidataintegrator) (3.0.9)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from rdflib>=0.4.2->cfgraph>=0.2.1->pyshex->wikidataintegrator) (57.0.0)
# Requirement already satisfied: isodate in ./venv/lib/python3.8/site-packages (from rdflib>=0.4.2->cfgraph>=0.2.1->pyshex->wikidataintegrator) (0.6.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./venv/lib/python3.8/site-packages (from requests->wikidataintegrator) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests->wikidataintegrator) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests->wikidataintegrator) (2022.5.18)
# Requirement already satisfied: rdflib-jsonld==0.6.1 in ./venv/lib/python3.8/site-packages (from rdflib-shim->pyshex->wikidataintegrator) (0.6.1)
# Requirement already satisfied: Flask-Cors in ./venv/lib/python3.8/site-packages (from shexer->wikidataintegrator) (3.0.10)
# Requirement already satisfied: Flask in ./venv/lib/python3.8/site-packages (from shexer->wikidataintegrator) (2.1.2)
# Requirement already satisfied: wlighter in ./venv/lib/python3.8/site-packages (from shexer->wikidataintegrator) (1.0.1)
# Requirement already satisfied: importlib-metadata>=3.6.0 in ./venv/lib/python3.8/site-packages (from Flask->shexer->wikidataintegrator) (4.11.3)
# Requirement already satisfied: click>=8.0 in ./venv/lib/python3.8/site-packages (from Flask->shexer->wikidataintegrator) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.0 in ./venv/lib/python3.8/site-packages (from Flask->shexer->wikidataintegrator) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in ./venv/lib/python3.8/site-packages (from Flask->shexer->wikidataintegrator) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in ./venv/lib/python3.8/site-packages (from Flask->shexer->wikidataintegrator) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.8/site-packages (from importlib-metadata>=3.6.0->Flask->shexer->wikidataintegrator) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.8/site-packages (from Jinja2>=3.0->Flask->shexer->wikidataintegrator) (2.1.1)
# WARNING: You are using pip version 21.1.2; however, version 22.1 is available.
# You should consider upgrading via the '/Users/andra/PycharmProjects/leapRDF/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install xlrd

# %%
from rdflib import Graph, URIRef, Literal, Namespace, BNode
import pandas as pd
from rdflib.namespace import RDF, RDFS, DCTERMS, DC
from wikidataintegrator import wdi_core

# %%
omeroRDF = Graph()
HPAS = Namespace("http://www.proteinatlas.org/search/")
OMERO = Namespace("https://idr.openmicroscopy.org/webclient/img_detail/")
WD = Namespace("http://www.wikidata.org/entity/")
WDP = Namespace("http://www.wikidata.org/prop/direct/")
wikidata = dict()

# %%
datasets = pd.read_csv("datasets.tsv", delimiter="\t", header=None)
datasetURIs = dict()
for index, row in datasets.iterrows():
    omeroRDF.add((HPAS[str(row[2])], RDFS.label, Literal(row[2])))
    datasetURIs[str(row[1])] = HPAS[str(row[2])]
    #omeroRDF.add((URIRef("http://deltatissue.net/project/"+str(row[1])), DCTERMS.isPartOf, URIRef("http://deltatissue.net/project/"+str(row[0]))))
datasets
# Out:
#          0      1          2   3
# 0      501   2302  HPA078571  \N
# 1      501   2303  HPA072942  \N
# 2      501   2304  HPA072449  \N
# 3      501   2305  HPA067601  \N
# 4      501   2307  CAB070868  \N
# ...    ...    ...        ...  ..
# 10995  501  16470  HPA034655  \N
# 10996  501  16471  HPA034656  \N
# 10997  501  16472  HPA034657  \N
# 10998  501  16473  HPA034659  \N
# 10999  501  16474  HPA034660  \N
#
# [11000 rows x 4 columns]

# %%
project_annotations = pd.read_csv("project_annotations.tsv", delimiter="\t", header=None)
project_annotations
# Out:
#       0         1                                  2                    3  \
# 0   501  20516223  idr.openmicroscopy.org/study/info          Sample Type
# 1   501  20516223  idr.openmicroscopy.org/study/info             Organism
# 2   501  20516223  idr.openmicroscopy.org/study/info          Study Title
# 3   501  20516223  idr.openmicroscopy.org/study/info           Study Type
# 4   501  20516223  idr.openmicroscopy.org/study/info       Imaging Method
# 5   501  20516223  idr.openmicroscopy.org/study/info    Publication Title
# 6   501  20516223  idr.openmicroscopy.org/study/info  Publication Authors
# 7   501  20516223  idr.openmicroscopy.org/study/info            PubMed ID
# 8   501  20516223  idr.openmicroscopy.org/study/info      Publication DOI
# 9   501  20516223  idr.openmicroscopy.org/study/info         Release Date
# 10  501  20516223  idr.openmicroscopy.org/study/info              License
# 11  501  20516223  idr.openmicroscopy.org/study/info            Copyright
# 12  501  20516223  idr.openmicroscopy.org/study/info       Data Publisher
# 13  501  20516223  idr.openmicroscopy.org/study/info         External URL
# 14  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 15  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 16  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 17  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 18  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 19  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 20  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 21  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 22  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 23  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
# 24  501  20516223  idr.openmicroscopy.org/study/info      Annotation File
#
#                                                     4
# 0                                              tissue
# 1                                        Homo sapiens
# 2              Tissue-based map of the human proteome
# 3                                protein localization
# 4                             bright-field microscopy
# 5   Proteomics. Tissue-based map of the human prot...
# 6   Uhlén M, Fagerberg L, Hallström BM, Lindskog C...
# 7   25613900 https://www.ncbi.nlm.nih.gov/pubmed/2...
# 8   10.1126/science.1260419 https://doi.org/10.112...
# 9                                          2018-11-01
# 10  CC BY-SA 3.0 https://v18.proteinatlas.org/abou...
# 11                                        Uhlen et al
# 12                               University of Dundee
# 13                       https://www.proteinatlas.org
# 14  idr0043-experimentA-annotation.csv.gz https://...
# 15  idr0043-experimentA-annotation.csv.gz https://...
# 16  idr0043-experimentA-annotation.csv.gz https://...
# 17  idr0043-experimentA-annotation.csv.gz https://...
# 18  idr0043-experimentA-annotation.csv.gz https://...
# 19  idr0043-experimentA-annotation.csv.gz https://...
# 20  idr0043-experimentA-annotation.csv.gz https://...
# 21  idr0043-experimentA-annotation.csv.gz https://...
# 22  idr0043-experimentA-annotation.csv.gz https://...
# 23  idr0043-experimentA-annotation.csv.gz https://...
# 24  idr0043-experimentA-annotation.csv.gz https://...

# %%
projects = pd.read_csv("projects.tsv", delimiter="\t", header=None)
projects
# Out:
#        0                                               1  \
# 0    201               idr0032-yang-meristem/experimentA
# 1    101         idr0018-neff-histopathology/experimentA
# 2    301      idr0026-weigelin-immunotherapy/experimentA
# 3    401            idr0040-aymoz-singlecell/experimentA
# 4     52      idr0023-szymborska-nuclearpore/experimentA
# ..   ...                                             ...
# 95  2103         idr0096-tratwal-marrowquant/experimentB
# 96  2104                     idr0096-tratwal-marrowquant
# 97  2151                idr0114-lindsay-hdbr/experimentA
# 98  2152    idr0068-shah-zebrafishlightsheet/experimentA
# 99  2201  idr0124-esteban-heartmorphogenesis/experimentA
#
#                                                     2
# 0   Publication Title\nRegulation of Meristem Morp...
# 1   Experiment Description\nHistopathology raw ima...
# 2   Publication Title\nFocusing and sustaining the...
# 3   Publication Title\nTiming of gene expression i...
# 4   Publication Title\nNuclear pore scaffold struc...
# ..                                                ...
# 95  Publication Title\nMarrowQuant in Aging and Ap...
# 96  Publication Title\nMarrowQuant in Aging and Ap...
# 97  Publication Title\nEnabling research with huma...
# 98  Publication Title\nMulti-scale imaging and ana...
# 99  Publication Title\nPseudo-dynamic analysis of ...
#
# [100 rows x 3 columns]

# %%
images = pd.read_csv("images.tsv", delimiter="\t", header=None)
imageURIs = dict()

for index, row in images.iterrows():
        omeroRDF.add((OMERO[str(row[2])], DCTERMS.isPartOf, datasetURIs[str(row[0])]))
        imageURIs[str(row[1])] = OMERO[str(row[2])]
images
# Out:
#             0        1                 2   3
# 0        8814  8361249  104975_A_2_5.tif  \N
# 1        8814  8361315  104975_A_8_7.tif  \N
# 2        8813  8361714  104648_A_9_7.tif  \N
# 3        8813  8361725  104648_A_8_4.tif  \N
# 4        8812  8362103  101966_A_3_4.tif  \N
# ...       ...      ...               ...  ..
# 5419120  6764  5979871  111621_A_1_5.tif  \N
# 5419121  6762  5981267  105999_A_6_1.tif  \N
# 5419122  6760  5982214  111491_B_8_4.tif  \N
# 5419123  6758  5982867  106182_A_5_6.tif  \N
# 5419124  6760  5982346  111491_B_9_2.tif  \N
#
# [5419125 rows x 4 columns]

# %%
imageURIs
# Out:
# {}

# %%
image_annotations  = pd.read_csv("image_annotations.tsv", delimiter="\t", header=None)
pd.set_option('display.max_rows', None)
for index,row in image_annotations.iterrows():
    thing = BNode()
    omeroRDF.add((OMERO[str(0)], WDP.P180, thing)) # P180 = depicts
    omeroRDF.add((thing, RDF.type, WD.Q35120)) # Q35120 = THING
    
    if str(row[3]) == "Organism":
        if str(row[4]) in wikidata.keys():
            omeroRDF.add((thing, WDP.P703, wikidata[row[4]])) # taxa -> Wikidata
        else:
            query = f"""
            SELECT * WHERE {{
               # ?taxon wdt:P225 "{row[4]}"
            }}
            """
            result = wdi_core.WDFunctionsEngine.execute_sparql_query(query)
            if len(result["results"]["bindings"])>0:
                wikidata[str(row[4])] = URIRef(result["results"]["bindings"][0]["taxon"]["value"])
            else:
                print("missing "+row[4]+" in wikidata")
            omeroRDF.add((thing, WDP.P703, wikidata[str(row[4])]))    

    if str(row[3]) == "Pathology Identifier":
       omeroRDF.add((thing, WDP.P1050, URIRef("http://purl.bioontology.org/ontology/SNMI/"+row[4]))

    if str(row[3]) == "Pathology":
        print(row[4])
        # typo's
        if row[4] == "Carcinoma, endometroid":
            row[4] = "Carcinoma, endometrioid"
        
        # list for curation
        tocurate = ["Malignant lymphoma, non-Hodgkin's type, Low grade",
                   "Malignant melanoma, NOS" # isn't melanoma malignant by default?
                   "Malignant melanoma, Metastatic site",
                   "Malignant melanoma, NOS",
                   "Malignant melanoma, Metastatic site",
                   "Adenocarcinoma, Low grade",
                   "Carcinoid, malignant, NOS",
                   "Normal tissue, NOS"]
        if row[4] in tocurate :
            continue
            
        if str(row[4]) in wikidata.keys():
            omeroRDF.add((thing, WDP.P1050, wikidata[row[4]])) # TODO incorrect Wikidata property
        else:
            query = f"""
            
            SELECT * WHERE {{
            VALUES ?pathology {{wd:Q12136}}
               {{?disease  wdt:P31 ?pathology .}}
                UNION
                {{?disease  wdt:P279 ?pathology .}}
                UNION
                {{?disease  wdt:P279/wdt:P31 ?pathology .}}
                UNION
                {{?disease  wdt:P279+ ?pathology .}}
               {{?disease rdfs:label "{row[4].lower()}"@en}}
               UNION
               {{?disease skos:altLabel "{row[4].lower()}"@en}}
            }}
            """
            print(query)
            result = wdi_core.WDFunctionsEngine.execute_sparql_query(query)
            if len(result["results"]["bindings"])>0:
                wikidata[str(row[4])] = URIRef(result["results"]["bindings"][0]["disease"]["value"])
            else:
                print("missing "+row[4]+" in wikidata")
            omeroRDF.add((thing, WDP.P827, wikidata[str(row[4])]))

        if str(row[3]) == "Organism Part Identifier":
            omeroRDF.add((thing, WDP.P361, URIRef("http://purl.bioontology.org/ontology/SNMI/"+str(row[4]))))

        if str(row[3]) == "Organism Part":
            print(row[4])
            if str(row[4]) in wikidata.keys():
                omeroRDF.add((thing, WDP.P361, wikidata[row[4]]))
            else:
                query = f"""

                SELECT * WHERE {{
                VALUES ?organ {{wd:Q103812529 wd:Q4936952 wd:Q712378 wd:Q24060765 wd:Q103843025 wd:Q27162596}}
                   {{?anatomical_structure  wdt:P31 ?organ .}}
                    UNION
                    {{?anatomical_structure  wdt:P279 ?organ .}}
                    UNION
                    {{?anatomical_structure  wdt:P279/wdt:P31 ?organ .}}
                    UNION
                    {{?anatomical_structure  wdt:P279+ ?organ .}}
                   {{?anatomical_structure rdfs:label "{row[4].lower()}"@en}}
                   UNION
                   {{?anatomical_structure skos:altLabel "{row[4].lower()}"@en}}
                }}
                """
                print(query)
                result = wdi_core.WDFunctionsEngine.execute_sparql_query(query)
                if len(result["results"]["bindings"])>0:
                    wikidata[str(row[4])] = URIRef(result["results"]["bindings"][0]["anatomical_structure"]["value"])
                else:
                    print("missing "+row[4]+" in wikidata")
                omeroRDF.add((thing, WDP.P827, wikidata[str(row[4])]))
            
    
    if str(row[3]) == "Sex":
        if row[4] == "Female":
            omeroRDF.add((thing, WDP.P21, WD.Q6581072))
        elif row[4] == "Male":
            omeroRDF.add((thing, WDP.P21, WD.Q6581097))
            
    if str(row[3]) == "Age":
        omeroRDF.add((thing, WDP.P3629, Literal(row[4])))
                   
    if str(row[3])== "Antibody Identifier URL":
        omeroRDF.add((thing, DC.identifier, URIRef(row[4])))
        
    if str(row[3])=="Gene Symbol":
        omeroRDF.add((thing, WDP.P353, Literal(row[4]))) # assumes homo sapiens
    
    if str(row[3]) =="Gene Identifier URL":
        omeroRDF.add((thing, DC.identifier, URIRef(row[4])))
        
        
    
    
image_annotations

# %%
print(omeroRDF.serialize(format="turtle", destination="hpa_omero.ttl"))

# %%
# !gzip hpa_omero.ttl
