# %%
# %%capture
# !pip install biopython
# !pip install wikidataintegrator
from wikidataintegrator import wdi_core, wdi_login, wdi_helpers
import getpass
import pandas as pd
from Bio import Entrez

# %%
print("username:")
username = input()
print("password:")
password = getpass.getpass()
login = wdi_login.WDLogin(user=username, pwd=password)
# Out:
# username:
# andrawaag
# password:
# ········

# %%
def search(query):
    Entrez.email = 'andra@micelio.be'
    handle = Entrez.esearch(db='pubmed',
                            sort='relevance',
                            retmax='500',
                            retmode='xml',
                            term=query)
    results = Entrez.read(handle)
    return results

def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'andra@micelio.be',
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    results = Entrez.read(handle)
    return results

def getDois(authorName):
    doiList = []
    results = fetch_details(search(authorName)['IdList'])
    for result in results["PubmedArticle"]:
        for id in result['PubmedData']['ArticleIdList']:
            if id.attributes['IdType'] == "doi":
                 doiList.append(str(id))
    return doiList

def create_or_get_wd(dois):
    for doi in dois:
        print(doi, wdi_helpers.PublicationHelper(doi, id_type="doi", source="crossref").get_or_create(login))

# %% [markdown]
# # Jason Swedlow
# Extracted list of DOIs from Pubmed

# %%
create_or_get_wd(getDois("Jason Swedlow[AU]"))
# Out:
# 10.1093/humrep/deac007 ('Q111442107', [], True)
# 10.1016/j.jmb.2022.167505 ('Q111442108', [], True)
# 10.1038/s41592-021-01387-x ('Q111442109', [], True)
# 10.1038/d41573-021-00196-3 ('Q111442112', [], True)
# 10.1530/REP-21-0372 ('Q111442113', [], True)
# 10.1038/s41592-021-01326-w ('Q111442114', [], True)
# 10.1038/s41592-021-01162-y ('Q111442118', [], True)
# 10.1038/s41592-022-01415-4 (None, [], KeyError('given'))
# 10.1038/s41592-021-01166-8 ('Q111441329', [], True)
# 10.1038/s41592-021-01113-7 ('Q111442122', [], True)
# 10.1038/d41586-021-02776-0 ('Q111442123', [], True)
# 10.1111/jmi.13041 ('Q111442124', [], True)
# 10.1093/gigascience/giaa041 ('Q94585053', [], True)
# 10.1021/acsnano.9b05891 ('Q92004876', [], True)
# 10.1007/978-3-030-23937-4_1 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1364/BOE.10.001999 ('Q62573482', [], True)
# 10.1038/s41592-018-0195-8 ('Q58083861', [], True)
# 10.1038/s41592-018-0169-x ('Q57030119', [], True)
# 10.1371/journal.ppat.1007230 ('Q57412200', [], True)
# 10.1098/rsob.170099 ('Q47139706', [], True)
# 10.1038/nmeth.4326 ('Q35065468', [], True)
# 10.7554/eLife.25835 ('Q38373358', [], True)
# 10.1371/journal.pgen.1006022 ('Q34526053', [], True)
# 10.1242/jcs.179911 ('Q36518627', [], True)
# 10.1016/j.ymeth.2015.10.006 ('Q28603486', [], True)
# 10.1016/j.devcel.2015.12.017 ('Q30846736', [], True)
# 10.1007/s00335-015-9587-6 ('Q28606500', [], True)
# 10.1016/j.tcb.2014.11.005 ('Q30487482', [], True)
# 10.1038/nsmb.2897 ('Q35136755', [], True)
# 10.3791/51420 ('Q34287216', [], True)
# 10.1128/JB.00930-13 ('Q30570510', [], True)
# 10.1016/j.jsb.2013.09.021 ('Q30674904', [], True)
# 10.1016/j.cell.2013.08.012 ('Q43983086', [], True)
# 10.1016/j.devcel.2013.06.014 ('Q28296254', [], True)
# 10.1038/ncb2695 ('Q24322683', [], True)
# 10.1016/B978-0-12-407761-4.00017-8 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/nsmb.2426 ('Q30580181', [], True)
# 10.1038/ncomms3677 ('Q28300849', [], True)
# 10.1016/B978-0-12-407761-4.00014-2 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/nmeth.2084 ('Q36861970', [], True)
# 10.3791/3920 ('Q42093139', [], True)
# 10.1002/bies.201100168 ('Q34191121', [], True)
# 10.1038/nmeth.1896 ('Q28260901', [], True)
# 10.1016/j.ceb.2012.01.012 ('Q57412224', [], True)
# 10.1101/pdb.top067504 ('Q34109627', [], True)
# 10.1371/journal.pone.0038102 ('Q34311816', [], True)
# 10.1186/1741-7007-9-58 ('Q34006424', [], True)
# 10.1101/pdb.ip87 ('Q52725453', [], True)
# 10.1101/pdb.top121 ('Q55054711', [], True)
# 10.1101/pdb.prot5657 ('Q52725444', [], True)
# 10.1007/s10577-011-9198-3 ('Q24613913', [], True)
# 10.1038/nmeth.1616 ('Q43550168', [], True)
# 10.1038/ncb0311-183 ('Q57412230', [], True)
# 10.1083/jcb.200912046 ('Q28294849', [], True)
# 10.1073/pnas.1010043107 ('Q30476411', [], True)
# 10.1083/jcb.201004104 ('Q28751859', [], True)
# service unavailable. sleeping for 60 seconds
# 10.1038/464684a ('Q53332080', [], True)
# 10.1083/jcb.200909005 ('Q28275327', [], True)
# 10.1091/mbc.e09-05-0377 ('Q42787426', [], True)
# 10.1016/j.tcb.2009.08.007 ('Q28749629', [], True)
# 10.1101/pdb.ip70 ('Q57412233', [], True)
# 10.1101/pdb.ip69 ('Q50564779', [], True)
# 10.1098/rsta.2009.0050 ('Q33447046', [], True)
# 10.1146/annurev.biophys.050708.133641 (None, [], KeyError('given'))
# 10.1016/j.cub.2008.04.075 ('Q39598250', [], True)
# 10.1038/nbt1391 ('Q28652074', [], True)
# 10.1016/S0091-679X(08)85024-8 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1111/j.1365-2818.2007.01861.x ('Q39529341', [], True)
# 10.1038/nsmb0907-788 ('Q50666505', [], True)
# 10.1083/jcb.200704098 ('Q30480574', [], True)
# 10.1016/j.cub.2007.08.041 ('Q42161292', [], True)
# 10.4161/cc.6.10.4179 ('Q40141531', [], True)
# 10.1242/dev.002519 ('Q51987359', [], True)
# 10.1016/S0091-679X(06)81021-6 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1016/S0091-679X(06)81017-4 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/ncb1496 ('Q31069199', [], True)
# 10.1089/omi.2006.10.205 ('Q36562145', [], True)
# 10.1186/gb-2005-6-5-r47 (None, [], IndexError('list index out of range'))
# 10.1186/1477-5956-2-6 (None, [], IndexError('list index out of range'))
# 10.1016/j.cub.2004.07.009 ('Q35842805', [], True)
# 10.1016/j.cub.2004.05.021 ('Q44940986', [], True)
# 10.1016/s1534-5807(04)00025-5 ('Q24307822', [], True)
# 10.1016/j.ceb.2003.10.013 ('Q35595904', [], True)
# 10.1016/s0092-8674(03)00465-3 ('Q24306616', [], True)
# 10.1126/science.1082602 ('Q28188875', [], True)
# 10.1016/s1097-2765(03)00103-5 ('Q34532415', [], True)
# 10.1016/s0091-679x(03)72017-2 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1091/mbc.e02-07-0376 ('Q39697073', [], True)
# 10.1016/s0962-8924(02)02387-5 ('Q57412259', [], True)
# 10.1247/csf.27.335 ('Q35034573', [], True)
# 10.1038/ncb809 ('Q44030629', [], True)
# 10.1073/pnas.022554999 ('Q31037649', [], True)
# 10.1034/j.1600-0854.2002.30105.x ('Q31040959', [], True)

# %% [markdown]
# ## Angus Lamond

# %%
create_or_get_wd(getDois("Angus Lamond[AU]"))
# Out:
# 10.1016/j.isci.2022.103827 ('Q111442137', [], True)
# 10.21769/BioProtoc.4106 ('Q111442138', [], True)
# 10.1093/nar/gkab465 ('Q110073995', [], True)
# 10.1038/s41556-022-00867-2 ('Q111442139', [], True)
# 10.7554/eLife.70055 ('Q111442140', [], True)
# 10.1038/s41467-020-18089-1 ('Q98725915', [], True)
# 10.7554/eLife.57390 (None, [], KeyError('given'))
# 10.1016/j.celrep.2021.109032 ('Q111442142', [], True)
# 10.12688/wellcomeopenres.15405.2 ('Q90890718', [], True)
# 10.1038/s41590-019-0495-x ('Q90576371', [], True)
# 10.12688/wellcomeopenres.15421.1 ('Q91085331', [], True)
# 10.1016/j.jaci.2019.05.024 ('Q92489299', [], True)
# 10.15252/embj.2020104419 ('Q94463039', [], True)
# 10.1074/mcp.RA119.001889 ('Q90051656', [], True)
# 10.1038/s41467-020-15173-4 ('Q90316968', [], True)
# 10.1093/bioinformatics/bty823 (None, [], ValueError("More than one wikidata ID found for P236 1367-4803: [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4914910'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27710219'}}]"))
# 10.1074/mcp.RA119.001472 ('Q92091558', [], True)
# 10.1073/pnas.1722299115 ('Q56753804', [], True)
# 10.12688/wellcomeopenres.14392.1 ('Q55153827', [], True)
# 10.7554/eLife.44210 ('Q64111220', [], True)
# 10.1534/g3.118.200874 ('Q90621917', [], True)
# 10.1016/j.cbpa.2018.10.011 ('Q90506518', [], True)
# 10.1093/nar/gkx807 ('Q42695063', [], True)
# 10.7554/eLife.36530 ('Q56529918', [], True)
# 10.7554/eLife.27574 ('Q42380836', [], True)
# 10.7554/eLife.27402 ('Q41664870', [], True)
# 10.1038/s41467-018-04719-2 ('Q55252861', [], True)
# 10.1074/mcp.RA118.000650 ('Q52648051', [], True)
# 10.1038/s41586-018-0032-3 ('Q52719957', [], True)
# 10.1091/mbc.E17-11-0627 ('Q47372394', [], True)
# 10.15252/embr.201641983 ('Q42319174', [], True)
# 10.1074/mcp.O117.068122 ('Q42697572', [], True)
# 10.7554/eLife.27356 ('Q47164119', [], True)
# 10.15252/msb.20167332 ('Q41789960', [], True)
# 10.1016/j.devcel.2017.07.002 ('Q41373535', [], True)
# 10.1016/j.cels.2017.06.004 ('Q42777160', [], True)
# 10.15252/embr.201643534 ('Q40980382', [], True)
# 10.1016/j.cels.2017.06.009 ('Q53188680', [], True)
# 10.1038/s41598-017-04375-4 ('Q38703734', [], True)
# 10.1038/nature23012 ('Q56902553', [], True)
# 10.1038/nature22403 ('Q42830893', [], True)
# 10.1074/mcp.O115.055467 ('Q38393244', [], True)
# 10.1093/nar/gkw209 ('Q27704509', [], True)
# 10.1371/journal.pone.0154759 ('Q36003437', [], True)
# 10.1074/jbc.M116.751024 ('Q39166548', [], True)
# 10.1007/978-1-4939-3792-9_21 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1016/j.cels.2016.06.011 ('Q28596873', [], True)
# 10.1371/journal.pone.0138668 ('Q35787589', [], True)
# 10.1074/mcp.M114.044289 ('Q28607125', [], True)
# 10.1002/pmic.201500264 ('Q28601346', [], True)
# 10.1007/978-1-4939-3792-9_20 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1242/jcs.179911 ('Q36518627', [], True)
# 10.1038/ni.3314 ('Q36389527', [], True)
# 10.1016/j.ijms.2015.07.029 ('Q40002655', [], True)
# 10.7554/eLife.04534 ('Q28650498', [], True)
# 10.1038/nrm3970 ('Q27008027', [], True)
# 10.1074/jbc.A114.590976 ('Q86886957', [], True)
# 10.1007/978-1-4939-2253-6_4 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1074/jbc.M114.590976 ('Q35301222', [], True)
# 10.1016/j.jviromet.2014.08.020 ('Q41751452', [], True)
# 10.1242/jcs.141788 ('Q37608722', [], True)
# 10.1083/jcb.201404160 ('Q34566711', [], True)
# 10.7554/eLife.01630 ('Q28658527', [], True)
# 10.1371/journal.pone.0072207 ('Q34973671', [], True)
# 10.4161/cc.25511 ('Q37344768', [], True)
# 10.1016/j.jprot.2013.02.023 ('Q37022960', [], True)
# 10.1016/j.tcb.2013.10.010 ('Q26823909', [], True)
# 10.1074/mcp.M113.032367 ('Q28661129', [], True)
# 10.1016/j.molcel.2012.12.023 ('Q24313202', [], True)
# 10.1098/rsob.130151 ('Q30558102', [], True)
# 10.1016/j.devcel.2013.06.014 ('Q28296254', [], True)
# 10.1371/journal.pone.0067689 ('Q34807927', [], True)
# 10.1371/journal.pone.0062305 ('Q34701211', [], True)
# 10.1074/mcp.M112.024547 ('Q39225646', [], True)
# 10.1074/mcp.O112.017731 ('Q42561146', [], True)
# 10.1371/journal.pone.0048084 ('Q27313223', [], True)
# 10.1371/journal.pone.0038102 ('Q34311816', [], True)
# 10.1002/prot.23186 ('Q27675295', [], True)
# 10.1007/s00412-011-0327-8 ('Q34194900', [], True)
# 10.1093/nar/gkr1233 ('Q35906056', [], True)
# 10.1038/nmeth.1679 ('Q38601965', [], True)
# 10.1074/mcp.M111.014407 ('Q35863296', [], True)
# 10.1074/mcp.M111.013680 ('Q41899128', [], True)
# 10.1074/mcp.M111.011429 ('Q35863277', [], True)
# 10.1371/journal.pone.0047497 ('Q28484594', [], True)
# 10.1002/pmic.201000548 ('Q34167937', [], True)
# 10.1074/mcp.M111.009241 ('Q35497627', [], True)
# 10.1042/BJ20110183 ('Q37002899', [], True)
# 10.1074/mcp.M110.005561 ('Q33877191', [], True)
# 10.1002/pmic.201000213 ('Q35590492', [], True)
# 10.1091/mbc.E10-06-0508 ('Q34136894', [], True)
# 10.1093/nar/gkq1355 ('Q28303599', [], True)
# 10.1016/j.molcel.2010.08.023 ('Q39652251', [], True)
# 10.1016/j.molcel.2010.07.025 ('Q34123821', [], True)
# 10.1101/cshperspect.a000646 ('Q34142111', [], True)
# 10.1038/embor.2010.64 ('Q24312238', [], True)
# 10.4161/nucl.2.1.14437 ('Q42180595', [], True)
# 10.1186/1471-2164-12-74 ('Q33805360', [], True)
# 10.1091/mbc.e10-01-0078 ('Q24630878', [], True)
# 10.1091/mbc.E10-04-0287 ('Q39647526', [], True)
# 10.1016/j.febslet.2010.10.044 ('Q42848350', [], True)
# 10.1093/nar/gkq653 ('Q39675144', [], True)
# 10.1016/j.molcel.2010.09.024 ('Q24597470', [], True)
# 10.1073/pnas.1004653107 ('Q34136544', [], True)
# 10.1038/ncb2092 ('Q24295682', [], True)
# 10.1101/cshperspect.a000687 ('Q33931966', [], True)
# 10.1074/mcp.M900517-MCP200 ('Q33519883', [], True)
# 10.1371/journal.pcbi.1000507 ('Q33504519', [], True)
# 10.1074/mcp.M900429-MCP200 ('Q33770130', [], True)
# 10.1074/mcp.M900338-MCP200 ('Q42935025', [], True)
# 10.1038/ncb1994 ('Q35014377', [], True)
# 10.1083/jcb.200907029 ('Q39769217', [], True)
# 10.1074/jbc.M109.036632 ('Q37431287', [], True)
# 10.1093/nar/gkn804 ('Q34872544', [], True)
# 10.1083/jcb.200805092 ('Q41783290', [], True)
# 10.1038/nbt0808-863 ('Q55050375', [], True)
# 10.1083/jcb.200710051 ('Q36718335', [], True)
# 10.1186/1471-2091-9-28 ('Q33383636', [], True)
# 10.1021/nn800461u ('Q57166285', [], True)
# 10.1074/mcp.M700173-MCP200 ('Q28253409', [], True)
# 10.1073/pnas.0804024105 ('Q36735152', [], True)
# 10.1016/j.febslet.2008.04.029 ('Q37149516', [], True)
# 10.1126/science.1142033 ('Q37019644', [], True)
# 10.1038/nrm2184 ('Q29615151', [], True)
# 10.1002/0471142956.cy1210s42 ('Q33366770', [], True)
# 10.1016/j.bbapap.2007.07.015 ('Q24294829', [], True)
# 10.1038/nsmb0907-788 ('Q50666505', [], True)
# 10.1083/jcb.200702147 ('Q24337867', [], True)
# 10.1385/1-59745-267-X:133 (None, ['unknown type: book-chapter', 'ISSN:[None] not found'], ValueError('can not create WDItemID with None'))
# 10.1074/mcp.M600212-MCP200 ('Q24304372', [], True)
# 10.1083/jcb.200604099 ('Q39745903', [], True)
# 10.1016/j.cub.2007.03.064 ('Q35830128', [], True)
# 10.1016/j.ceb.2006.09.001 ('Q36618472', [], True)
# 10.1038/ncb1475 ('Q42238919', [], True)
# 10.1261/rna.7277705 ('Q38323211', [], True)
# 10.1083/jcb.200508154 ('Q30480368', [], True)
# 10.1093/nar/gkj004 ('Q25257475', [], True)
# 10.1093/nar/gki986 ('Q24298242', [], True)
# 10.1091/mbc.e05-06-0587 ('Q22066089', [], True)
# 10.1074/jbc.M501982200 ('Q24312861', [], True)
# 10.1242/jcs.01736 ('Q57166314', [], True)
# 10.1146/annurev.cellbio.20.010403.103738 ('Q22065410', [], True)
# 10.1091/mbc.e04-09-0791 ('Q33564752', [], True)
# 10.1042/BJ20041517 ('Q24529004', [], True)
# 10.1038/nature03207 ('Q21735921', [], True)
# 10.1083/jcb.200407182 ('Q24678676', [], True)
# 10.1083/jcb.200405013 ('Q42915416', [], True)
# 10.1016/j.yexcr.2003.11.020 ('Q24311579', [], True)
# 10.1074/jbc.M404201200 ('Q28264738', [], True)
# 10.1007/978-3-540-74266-1_1 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1042/BJ20031169 ('Q35553216', [], True)
# 10.1093/nar/gkg817 ('Q24644221', [], True)
# 10.1016/s0006-291x(03)01486-4 ('Q24316802', [], True)
# 10.1038/nrm1172 ('Q22121993', [], True)
# 10.1242/jcs.00400 ('Q28189028', [], True)
# 10.1016/j.cub.2003.10.012 ('Q33973582', [], True)
# 10.1093/emboj/cdf652 ('Q24539224', [], True)
# 10.1242/jcs.00409 ('Q28187838', [], True)
# 10.1101/gr.473902 ('Q24671785', [], True)
# 10.1615/critreveukaryotgeneexpr.v13.i1.40 ('Q35168228', [], True)
# 10.1091/mbc.e02-07-0376 ('Q39697073', [], True)
# 10.1038/ncb809 ('Q44030629', [], True)
# 10.1017/s1355838202020022 ('Q24540106', [], True)
# 10.1016/s0092-8674(02)00730-4 ('Q28217970', [], True)
# 10.1083/jcb.200201120 ('Q24671777', [], True)
# 10.1083/jcb.200206111 ('Q24672790', [], True)
# 10.1091/mbc.02-03-0034 ('Q33960367', [], True)
# 10.1016/s0960-9822(01)00650-9 ('Q24292165', [], True)
# 10.1100/tsw.2002.43 ('Q55405866', [], True)
# 10.1186/gb-2002-3-6-reports4016 (None, [], IndexError('list index out of range'))
# 10.1016/s0960-9822(01)00632-7 ('Q29397010', [], True)

# %% [markdown]
# # Tom Owen-Hughes

# %%
create_or_get_wd(getDois("Tom Owen-Hughes[AU]"))
# Out:
# 10.1016/j.celrep.2021.109943 ('Q111442182', [], True)
# 10.1016/j.gde.2020.11.003 ('Q104106137', [], True)
# 10.12688/f1000research.21933.1 ('Q99630524', [], True)
# 10.1016/j.cell.2019.08.024 ('Q93151283', [], True)
# 10.1038/s41589-019-0329-z ('Q91565780', [], True)
# 10.1038/s41589-019-0294-6 ('Q92616532', [], True)
# 10.7554/eLife.36530 ('Q56529918', [], True)
# 10.1371/journal.pgen.1007783 ('Q59810745', [], True)
# 10.7554/eLife.35720 ('Q56530225', [], True)
# 10.7554/eLife.22510 ('Q41850902', [], True)
# 10.1038/nsmb.3347 ('Q48372682', [], True)
# 10.1093/nar/gkw331 ('Q41005325', [], True)
# 10.1016/j.celrep.2017.02.045 ('Q51116901', [], True)
# 10.1126/science.aam5403 ('Q51180482', [], True)
# 10.1261/rna.058339.116 ('Q41131980', [], True)
# 10.1186/s12860-016-0111-y ('Q27318586', [], True)
# 10.1093/nar/gkw209 ('Q27704509', [], True)
# 10.1261/rna.053959.115 ('Q38889056', [], True)
# 10.1371/journal.pgen.1005940 ('Q34520034', [], True)
# 10.1093/bioinformatics/btv425 (None, [], ValueError("More than one wikidata ID found for P236 1367-4803: [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4914910'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27710219'}}]"))
# 10.1016/j.ymeth.2014.10.028 ('Q43076926', [], True)
# 10.1016/j.jmr.2014.09.010 ('Q30602280', [], True)
# 10.7554/eLife.01632 ('Q38499414', [], True)
# 10.1093/nar/gku232 ('Q39769792', [], True)
# 10.1016/j.jmb.2013.07.019 ('Q37504982', [], True)
# 10.1016/j.molcel.2013.07.016 ('Q34366324', [], True)
# 10.1016/j.cell.2013.07.011 ('Q38126255', [], True)
# 10.1038/nsmb.2446 ('Q30531468', [], True)
# 10.1038/nsmb.2574 ('Q36912565', [], True)
# 10.1016/j.jmb.2012.04.031 ('Q41853168', [], True)
# 10.1186/gb4046 ('Q41431633', [], True)
# 10.1016/j.ceb.2012.02.003 ('Q37992785', [], True)
# 10.1016/j.jmb.2012.01.043 ('Q35859472', [], True)
# 10.1126/science.1206097 ('Q42146780', [], True)
# 10.1007/978-1-61779-477-3_22 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/emboj.2011.166 ('Q27668078', [], True)
# 10.1016/j.cbpa.2011.07.022 ('Q37921466', [], True)
# 10.1111/j.1742-4658.2011.08281.x ('Q34170937', [], True)
# 10.1038/emboj.2011.112 ('Q42051038', [], True)
# 10.1016/j.molcel.2011.01.025 ('Q34978251', [], True)
# 10.1016/j.molcel.2010.12.008 ('Q36238038', [], True)
# 10.1016/j.jmr.2010.08.002 ('Q30529330', [], True)
# 10.1016/j.cell.2010.10.021 ('Q51831502', [], True)
# 10.1093/nar/gkp1003 ('Q30492887', [], True)
# 10.1016/j.molcel.2009.07.027 ('Q40097842', [], True)
# 10.1074/jbc.M109.082149 ('Q27939866', [], True)
# 10.1126/science.1177321 ('Q24321560', [], True)
# 10.1128/MCB.00400-09 ('Q42579967', [], True)
# 10.1074/jbc.M109.005421 ('Q34975324', [], True)
# 10.1093/nar/gkp114 ('Q33415282', [], True)
# 10.1038/emboj.2009.33 ('Q24310508', [], True)
# 10.1038/nsmb.1551 ('Q43136918', [], True)
# 10.1021/ja807918f ('Q24610040', [], True)
# 10.1074/jbc.M806830200 ('Q41983584', [], True)
# 10.1021/bi8016944 ('Q36192757', [], True)
# 10.1002/jbio.200810027 ('Q24610770', [], True)
# 10.1016/j.jmb.2007.09.059 ('Q27934508', [], True)
# 10.1128/MCB.02229-06 ('Q35857015', [], True)
# 10.1186/gb-2007-8-6-217 ('Q36865040', [], True)
# 10.1038/nsmb1206-1047 ('Q60489236', [], True)
# 10.1093/nar/gkl295 ('Q41900203', [], True)
# 10.1016/j.molcel.2005.12.013 ('Q24599789', [], True)
# 10.1074/jbc.M600682200 ('Q27938565', [], True)
# 10.1093/nar/gkl540 ('Q36578937', [], True)
# 10.1042/bss0730109 ('Q36454299', [], True)
# 10.1021/bi047634t ('Q46605909', [], True)
# 10.1038/sj.onc.1208025 ('Q34349617', [], True)
# 10.1016/s0076-6879(03)75014-9 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1126/science.1093990 ('Q44730706', [], True)
# 10.1016/j.gde.2004.01.007 ('Q35804610', [], True)
# 10.1016/j.dnarep.2003.11.004 ('Q27933692', [], True)
# 10.1128/MCB.23.21.7767-7779.2003 ('Q39940474', [], True)
# 10.1038/sj.emboj.7600047 ('Q39318944', [], True)
# 10.1016/s1097-2765(03)00499-4 ('Q24611081', [], True)
# 10.1002/bip.10323 ('Q28187529', [], True)
# 10.1128/MCB.23.6.1935-1945.2003 ('Q38357160', [], True)
# 10.1091/mbc.01-10-0484 ('Q24299539', [], True)

# %% [markdown]
# # Julian Blow

# %%
create_or_get_wd(getDois("Julian Blow[AU]"))
# Out:
# 10.1098/rsob.210121 ('Q111442196', [], True)
# 10.1021/acs.jmedchem.1c01532 ('Q111442197', [], True)
# 10.1083/jcb.201905181 ('Q91563646', [], True)
# 10.1038/s41467-018-06066-8 ('Q58747295', [], True)
# 10.1002/cbic.201700500 ('Q47309289', [], True)
# 10.1083/jcb.201708023 ('Q52723140', [], True)
# 10.1016/j.chembiol.2017.06.019 ('Q41461302', [], True)
# 10.1073/pnas.1603241113 ('Q37304838', [], True)
# 10.1016/j.celrep.2017.02.042 ('Q42136223', [], True)
# 10.1371/journal.pgen.1005872 ('Q27309114', [], True)
# 10.1073/pnas.1603252113 ('Q37304981', [], True)
# 10.1080/15384101.2016.1199305 ('Q39666879', [], True)
# 10.1007/978-1-4939-2957-3_6 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/ncb3378 ('Q39669947', [], True)
# 10.1016/j.celrep.2016.03.078 ('Q36850235', [], True)
# 10.1016/j.bbamcr.2015.12.019 ('Q52890738', [], True)
# 10.1126/science.aad5634 ('Q28272401', [], True)
# 10.1387/ijdb.160142jb ('Q48539046', [], True)
# 10.1038/ncomms7352 ('Q43180171', [], True)
# 10.1016/j.celrep.2015.06.046 ('Q35905496', [], True)
# 10.1038/ncomms6485 ('Q30608755', [], True)
# 10.7554/eLife.02863 ('Q34117004', [], True)
# 10.1016/j.dnarep.2014.03.012 ('Q38207300', [], True)
# 10.1101/gad.226373.113 ('Q35057886', [], True)
# 10.1074/jbc.M113.491928 ('Q27680038', [], True)
# 10.1016/j.devcel.2013.06.014 ('Q28296254', [], True)
# 10.1098/rsob.130138 ('Q41809632', [], True)
# 10.1016/j.molcel.2013.05.011 ('Q27940145', [], True)
# 10.1093/nar/gkt728 ('Q37327579', [], True)
# 10.1083/jcb.201306143 ('Q41997371', [], True)
# 10.1101/cshperspect.a012955 ('Q38035836', [], True)
# 10.4161/cc.24310 ('Q42141837', [], True)
# 10.1371/journal.pgen.1003591 ('Q27321712', [], True)
# 10.1083/jcb.201110080 ('Q35694176', [], True)
# 10.1016/j.ymeth.2012.03.029 ('Q36220565', [], True)
# 10.1242/jcs.100883 ('Q36348378', [], True)
# 10.4161/nucl.2.5.17859 ('Q35878801', [], True)
# 10.1103/PhysRevLett.108.058101 ('Q51406714', [], True)
# 10.1016/j.tibs.2011.05.002 ('Q37884997', [], True)
# 10.1242/dev.068676 ('Q36382165', [], True)
# 10.1016/j.molcel.2011.08.028 ('Q36192735', [], True)
# 10.1074/jbc.M110.199521 ('Q42174550', [], True)
# 10.1016/j.bbamcr.2011.01.002 ('Q36193430', [], True)
# 10.1016/j.molcel.2011.02.014 ('Q41812634', [], True)
# 10.1083/jcb.201007074 ('Q39617777', [], True)
# 10.4161/cc.9.16.12644 ('Q41813815', [], True)
# 10.1016/j.molcel.2009.12.028 ('Q42915399', [], True)
# 10.1083/jcb.200911037 ('Q42929219', [], True)
# 10.1038/embor.2009.5 ('Q41869620', [], True)
# 10.1016/j.cub.2008.04.075 ('Q39598250', [], True)
# 10.1038/nrc2500 ('Q24644766', [], True)
# 10.1016/j.yexcr.2008.05.009 ('Q36960851', [], True)
# 10.1016/j.dnarep.2008.02.001 ('Q28509424', [], True)
# 10.1186/gb-2008-9-12-244 ('Q37368527', [], True)
# 10.1101/gad.457807 ('Q40035632', [], True)
# 10.1083/jcb.200704098 ('Q30480574', [], True)
# 10.1016/j.cub.2007.08.041 ('Q42161292', [], True)
# 10.1038/sj.embor.7400954 ('Q36777288', [], True)
# 10.1016/j.molcel.2006.09.010 ('Q41965807', [], True)
# 10.1083/jcb.200602108 ('Q39729829', [], True)
# 10.1016/j.ceb.2006.04.001 ('Q36464843', [], True)
# 10.1016/j.cell.2006.04.041 ('Q42164459', [], True)
# 10.1038/sj.embor.7400557 ('Q24537591', [], True)
# 10.1093/nar/gki539 ('Q24793913', [], True)
# 10.1038/nrm1663 ('Q24653685', [], True)
# 10.1093/nar/gki176 ('Q24794160', [], True)
# 10.1242/jcs.01400 ('Q41846285', [], True)
# 10.1186/1477-5956-2-6 (None, [], IndexError('list index out of range'))
# 10.1038/sj.emboj.7600520 ('Q40949803', [], True)
# 10.1242/jcs.01503 ('Q40496514', [], True)
# 10.1038/ncb1100 ('Q37214163', [], True)
# 10.1186/1471-2199-5-5 (None, [], IndexError('list index out of range'))
# 10.1083/jcb.200311044 ('Q36321891', [], True)
# 10.1038/423818b ('Q43195239', [], True)
# 10.1016/s0092-8674(03)00236-8 ('Q43221313', [], True)
# 10.1038/sj.onc.1205910 ('Q43219572', [], True)
# 10.1016/s0960-9822(02)00778-9 ('Q36708719', [], True)
# 10.1016/s0962-8924(01)02203-6 ('Q34534992', [], True)
# 10.1242/jcs.115.1.51 ('Q111442214', [], True)

# %% [markdown]
# # Ronald Hay

# %%
create_or_get_wd(getDois("Ronald Hay[AU]"))
# Out:
# 10.3389/fcell.2022.743287 ('Q111442215', [], True)
# 10.1042/BCJ20210256 ('Q111442216', [], True)
# 10.1083/jcb.202005130 ('Q111442217', [], True)
# 10.15252/embj.2020107413 ('Q111442218', [], True)
# 10.1016/j.mcpro.2021.100164 ('Q111442219', [], True)
# 10.1038/s41467-020-17647-x ('Q98177170', [], True)
# 10.1016/j.isci.2020.101638 ('Q100995088', [], True)
# 10.1016/j.molcel.2020.04.032 ('Q95847924', [], True)
# 10.3390/cells9030777 ('Q90631620', [], True)
# 10.1038/s41467-020-16666-y ('Q96171834', [], True)
# 10.1016/j.chembiol.2019.11.013 ('Q92142744', [], True)
# 10.1016/j.molcel.2019.06.002 ('Q93114616', [], True)
# 10.1371/journal.pgen.1008427 ('Q91439426', [], True)
# 10.1242/jcs.232330 ('Q93051383', [], True)
# 10.1073/pnas.1907031116 ('Q92482312', [], True)
# 10.1016/j.isci.2019.05.028 ('Q92660613', [], True)
# 10.1016/bs.mie.2018.11.005 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1016/j.celrep.2018.09.080 ('Q57796342', [], True)
# 10.1016/j.celrep.2018.04.022 ('Q55303071', [], True)
# 10.7554/eLife.27402 ('Q41664870', [], True)
# 10.1096/fj.201600713R ('Q40310580', [], True)
# 10.1016/j.molcel.2016.11.001 ('Q37574622', [], True)
# 10.1016/j.celrep.2017.03.020 ('Q41829436', [], True)
# 10.1074/mcp.O116.065219 ('Q28817404', [], True)
# 10.1038/srep26178 ('Q39761629', [], True)
# 10.1016/j.celrep.2015.10.001 ('Q36320597', [], True)
# 10.1242/jcs.176446 ('Q35870845', [], True)
# 10.1007/978-1-4939-6358-4_17 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/srep18940 ('Q38805774', [], True)
# 10.1073/pnas.1509716112 ('Q36055482', [], True)
# 10.1038/ncomms9827 ('Q36341346', [], True)
# 10.1371/journal.ppat.1005059 ('Q35705640', [], True)
# 10.1038/nprot.2015.095 ('Q40623371', [], True)
# 10.1038/nsmb.3052 ('Q42095239', [], True)
# 10.1126/scisignal.aaa2213 ('Q38855621', [], True)
# 10.1042/BJ20141349 ('Q43180105', [], True)
# 10.1038/ncomms7352 ('Q43180171', [], True)
# 10.1038/srep09811 ('Q38881071', [], True)
# 10.1038/ncomms6485 ('Q30608755', [], True)
# 10.1016/j.molcel.2014.09.008 ('Q43006495', [], True)
# 10.15252/embr.201338386 ('Q41840965', [], True)
# 10.1038/ncomms5426 ('Q34009850', [], True)
# 10.1038/ncomms5217 ('Q27684476', [], True)
# 10.3791/51572 ('Q35180933', [], True)
# 10.1016/j.molonc.2014.04.002 ('Q38996247', [], True)
# 10.1016/j.molcel.2014.02.031 ('Q38823924', [], True)
# 10.1126/scisignal.2005146 ('Q39201092', [], True)
# 10.1158/0008-5472.CAN-13-2131 ('Q35135920', [], True)
# 10.1093/jmcb/mjt032 ('Q39091679', [], True)
# 10.1242/jcs.132290 ('Q41867398', [], True)
# 10.1073/pnas.1311382110 ('Q37318235', [], True)
# 10.1042/BJ20130244 ('Q34337452', [], True)
# 10.1042/BST20130015 ('Q38091465', [], True)
# 10.1042/BJ20130026 ('Q39196735', [], True)
# 10.1038/nature11376 ('Q27670947', [], True)
# 10.1038/nmeth.2106 ('Q42321488', [], True)
# 10.1242/jcs.102889 ('Q42115226', [], True)
# 10.1101/gad.189274.112 ('Q28569714', [], True)
# 10.1007/978-1-61779-474-2_17 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1021/pr2004715 ('Q38660711', [], True)
# 10.1038/nsmb.2108 ('Q27671855', [], True)
# 10.1126/scisignal.2001484 ('Q27865258', [], True)
# 10.1038/nmeth.1679 ('Q38601965', [], True)
# 10.1042/BJ20101487 ('Q39807649', [], True)
# 10.1091/mbc.E10-05-0449 ('Q24302645', [], True)
# 10.1016/j.tox.2010.07.013 ('Q27865254', [], True)
# 10.1038/embor.2010.206 ('Q24337826', [], True)
# 10.1091/mbc.E10-06-0504 ('Q41669688', [], True)
# 10.1038/ncb2112 ('Q34352467', [], True)
# 10.1038/nprot.2010.40 ('Q39709060', [], True)
# 10.1016/j.biocel.2010.01.010 ('Q39751187', [], True)
# 10.1002/ejoc.200901016 ('Q39869217', [], True)
# 10.1038/nrm2707 ('Q37498263', [], True)
# 10.1126/scisignal.2000282 ('Q27865236', [], True)
# 10.1042/BJ20090246 ('Q44156118', [], True)
# 10.1038/nprot.2009.128 ('Q60304832', [], True)
# 10.1007/978-1-59745-566-4_17 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1101/gad.494808 ('Q36898100', [], True)
# 10.1038/ncb1716 ('Q24320385', [], True)
# 10.1038/embor.2008.10 ('Q24313502', [], True)
# 10.1038/nature06883 ('Q24336879', [], True)
# 10.1158/0008-5472.CAN-07-2092 ('Q46670117', [], True)
# 10.1110/ps.073369608 ('Q36503296', [], True)
# 10.1016/j.jhep.2007.12.019 ('Q54546261', [], True)
# 10.1074/mcp.M700173-MCP200 ('Q28253409', [], True)
# 10.1128/MCB.01811-06 ('Q35950115', [], True)
# 10.1042/BJ20061451 ('Q40161850', [], True)
# 10.1016/j.tcb.2007.08.002 ('Q36927821', [], True)
# 10.1016/j.ab.2006.12.018 ('Q60304859', [], True)
# 10.1073/pnas.0608773104 ('Q35691065', [], True)
# 10.1038/nsmb1172 ('Q24596746', [], True)
# 10.1073/pnas.0606877103 ('Q24304828', [], True)
# 10.1074/mcp.M600212-MCP200 ('Q24304372', [], True)
# 10.1042/BJ20052030 ('Q24553350', [], True)
# 10.1016/j.ymeth.2005.07.020 ('Q46847586', [], True)
# 10.1021/ac058019d ('Q46727990', [], True)
# 10.1074/jbc.M503921200 ('Q40409213', [], True)
# 10.1038/sj.emboj.7600628 ('Q24529121', [], True)
# 10.1016/j.molcel.2005.03.012 ('Q28243325', [], True)
# 10.1038/nsmb878 ('Q28119055', [], True)
# 10.1016/j.bbrc.2004.11.090 ('Q45185295', [], True)
# 10.1074/jbc.M408748200 ('Q24337470', [], True)
# 10.4161/cc.4.1.1359 ('Q40478393', [], True)
# 10.1021/ac0401063 ('Q33209458', [], True)
# 10.1016/j.molcel.2004.11.007 ('Q28293640', [], True)
# 10.1074/jbc.M404201200 ('Q28264738', [], True)
# 10.1016/j.jmb.2004.06.004 ('Q60304899', [], True)
# 10.1016/j.cell.2004.06.016 ('Q28270986', [], True)
# 10.1016/j.semcdb.2003.12.001 ('Q28647169', [], True)
# 10.1038/ncb0204-89 ('Q60304917', [], True)
# 10.1016/j.bpc.2003.10.032 ('Q42623283', [], True)
# 10.1016/s0167-4889(03)00084-3 ('Q38350447', [], True)
# 10.1021/bi0345283 ('Q28202247', [], True)
# 10.1074/jbc.M212948200 ('Q28202321', [], True)
# 10.1016/s1097-2765(03)00141-2 ('Q60304936', [], True)
# 10.1021/bi026861x ('Q27863763', [], True)
# 10.1128/MCB.23.1.402-413.2003 ('Q28118570', [], True)
# 10.1016/s0014-5793(02)03310-0 ('Q40701686', [], True)
# 10.1074/jbc.M108418200 ('Q43904668', [], True)
# 10.1002/1521-4141(200202)32:2<457::AID-IMMU457>3.0.CO;2-1 ('Q43867812', [], True)
# 10.1099/0022-1317-82-8-1917 ('Q40791862', [], True)

# %% [markdown]
# # Victoria Cowling

# %%
create_or_get_wd(getDois("Victoria Cowling[AU]"))
# Out:
# 10.1016/j.jmb.2022.167451 ('Q111442246', [], True)
# 10.1093/nar/gkac122 ('Q111442247', [], True)
# 10.1136/emermed-2020-209797 ('Q97566417', [], True)
# 10.1042/BCJ20210219 ('Q111442249', [], True)
# 10.1093/nar/gkab465 ('Q110073995', [], True)
# 10.1177/24725552211000652 ('Q111442250', [], True)
# 10.1093/nar/gkab130 ('Q111442251', [], True)
# 10.1098/rsob.190306 ('Q89876922', [], True)
# 10.1073/pnas.2002360117 ('Q100550292', [], True)
# 10.1002/chem.202001036 ('Q91661050', [], True)
# 10.1098/rsob.190052 ('Q64106179', [], True)
# 10.1016/j.bbagrm.2018.09.011 ('Q57479681', [], True)
# 10.1093/nar/gkz613 ('Q92075235', [], True)
# 10.26508/lsa.201800092 ('Q57753844', [], True)
# 10.1016/j.celrep.2018.04.004 ('Q52714681', [], True)
# 10.1016/j.tibs.2019.01.002 ('Q64085149', [], True)
# 10.1002/wrna.1450 ('Q47710506', [], True)
# 10.1371/journal.pone.0201263 ('Q58867158', [], True)
# 10.1080/15476286.2018.1460996 ('Q52316043', [], True)
# 10.1016/j.celrep.2016.06.089 ('Q41786413', [], True)
# 10.1042/BCJ20160930 ('Q41768979', [], True)
# 10.1016/j.molcel.2016.02.008 ('Q38824694', [], True)
# 10.1080/15476286.2016.1251540 ('Q43071071', [], True)
# 10.18632/oncotarget.12701 ('Q42316813', [], True)
# 10.1093/nar/gkw637 ('Q27719999', [], True)
# 10.15252/embj.201490252 ('Q40293369', [], True)
# 10.1038/ncomms7569 ('Q41179648', [], True)
# 10.1242/jcs.176693 ('Q48028384', [], True)
# 10.1016/j.bbagrm.2014.03.007 ('Q38200434', [], True)
# 10.1042/BJ20131214 ('Q38172648', [], True)
# 10.1042/BJ20131359 ('Q39066290', [], True)
# 10.1371/journal.pone.0077537 ('Q35025500', [], True)
# 10.1042/BJ20130378 ('Q37186872', [], True)
# 10.4161/cc.20620 ('Q42185668', [], True)
# 10.1016/j.molcel.2011.08.041 ('Q24297879', [], True)
# 10.1042/BST0381598 ('Q42789906', [], True)
# 10.1042/BJ20091352 ('Q24644921', [], True)
# 10.1177/1947601910378025 ('Q34407825', [], True)
# 10.1371/journal.pone.0006693 ('Q33494820', [], True)
# 10.1128/MCB.00973-09 ('Q39791099', [], True)
# 10.1038/nrm2467 ('Q37242438', [], True)
# 10.4161/cc.6.21.4880 ('Q36921878', [], True)
# 10.1128/MCB.02282-06 ('Q35949600', [], True)
# 10.1158/0008-5472.CAN-05-4571 ('Q40181736', [], True)
# 10.4161/cc.6.8.4123 ('Q52678516', [], True)
# 10.1128/MCB.01828-06 ('Q28567657', [], True)
# 10.1016/j.semcancer.2006.08.001 ('Q36578696', [], True)
# 10.1128/MCB.01959-05 ('Q34718058', [], True)
# 10.1016/j.molcel.2005.10.038 ('Q33228925', [], True)
# 10.1074/jbc.M308659200 ('Q31002776', [], True)

# %% [markdown]
# # Kasper Lippert-Rasmussen

# %%
create_or_get_wd(getDois("Kasper Lippert-Rasmussen[AU]"))
# Out:
# 10.1136/medethics-2020-106078 ('Q89701024', [], True)
# 10.1111/bioe.12908 ('Q111442269', [], True)
# 10.1136/medethics-2015-103360 ('Q87381739', [], True)
# 10.1136/medethics-2012-100580 ('Q58664869', [], True)
# 10.1136/medethics-2011-100163 ('Q48516367', [], True)
# 10.1007/s11019-010-9240-9 ('Q48857652', [], True)

# %% [markdown]
# # Tomoyuki U Tanaka

# %%
create_or_get_wd(getDois("Tomoyuki U Tanaka[AU]"))
# Out:
# 10.1002/bies.202100246 ('Q111442270', [], True)
# 10.1083/jcb.202011117 ('Q111442272', [], True)
# 10.1080/15384101.2020.1757242 ('Q94656800', [], True)
# 10.1016/j.molcel.2020.04.036 ('Q95650889', [], True)
# 10.7554/eLife.46902 ('Q83231218', [], True)
# 10.1016/j.cub.2019.03.051 ('Q64065354', [], True)
# 10.1083/jcb.201807125 ('Q64107981', [], True)
# 10.1242/jcs.203000 ('Q38762817', [], True)
# 10.1016/j.molcel.2017.10.009 ('Q44076675', [], True)
# 10.1083/jcb.201608122 ('Q38818100', [], True)
# 10.1186/s12860-016-0111-y ('Q27318586', [], True)
# 10.1038/ncb3128 ('Q41790587', [], True)
# 10.1016/j.cub.2015.06.023 ('Q42436460', [], True)
# 10.1038/ncb3153 ('Q86998659', [], True)
# 10.1038/embor.2013.181 ('Q27008596', [], True)
# 10.1016/j.celrep.2013.10.014 ('Q41885231', [], True)
# 10.1016/j.molcel.2013.05.011 ('Q27940145', [], True)
# 10.1083/jcb.201306143 ('Q41997371', [], True)
# 10.1016/j.devcel.2011.09.006 ('Q41050003', [], True)
# 10.1038/ncb2495 ('Q27937573', [], True)
# 10.1016/j.cub.2010.12.050 ('Q42056835', [], True)
# 10.1038/emboj.2011.112 ('Q42051038', [], True)
# 10.1016/j.ymeth.2010.01.017 ('Q34195835', [], True)
# 10.1038/emboj.2010.294 ('Q24602097', [], True)
# 10.1016/j.devcel.2010.07.013 ('Q41964495', [], True)
# 10.1007/s10577-009-9088-0 ('Q37621327', [], True)
# 10.1242/jcs.055566 ('Q41837810', [], True)
# 10.1016/j.devcel.2009.12.018 ('Q39277128', [], True)
# 10.1007/978-1-60327-993-2_14 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1016/j.jsb.2008.03.015 ('Q41622762', [], True)
# 10.1007/s00412-008-0173-5 ('Q37234477', [], True)
# 10.1101/gad.449407 ('Q41448908', [], True)
# 10.1016/j.cub.2007.11.032 ('Q27930787', [], True)
# 10.1016/j.ceb.2007.11.005 ('Q36606737', [], True)
# 10.1083/jcb.200702141 ('Q27936713', [], True)
# 10.1038/ncb1462 ('Q27939784', [], True)
# 10.1016/j.cell.2006.04.041 ('Q42164459', [], True)
# 10.1038/sj.embor.7400557 ('Q24537591', [], True)
# 10.1038/nrm1764 ('Q36337950', [], True)
# 10.1038/nature03483 ('Q48951524', [], True)
# 10.1098/rstb.2004.1612 (None, [], ValueError("More than one wikidata ID found for P236 0962-8436: [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2153239'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q36250502'}}]"))
# 10.1038/nature02328 ('Q34298424', [], True)
# 10.1016/s1534-5807(03)00086-8 ('Q27939356', [], True)
# 10.1016/s0955-0674(02)00328-9 ('Q34688467', [], True)
# 10.1016/s0092-8674(02)00633-5 ('Q29619579', [], True)
# 10.1093/emboj/21.1.181 ('Q39646433', [], True)

# %% [markdown]
# # Tony Ly

# %%
create_or_get_wd(getDois("Tony Ly[AU]"))
# Out:
# 10.15252/embj.2021108599 ('Q111442280', [], True)
# 10.1016/j.mcpro.2021.100169 ('Q111442281', [], True)
# 10.1083/jcb.202009167 ('Q104682651', [], True)
# 10.3389/fcell.2021.727441 ('Q111442282', [], True)
# 10.1038/s41598-021-86070-z ('Q111442283', [], True)
# 10.15252/embj.2020104419 ('Q94463039', [], True)
# 10.1242/jcs.234401 ('Q90637868', [], True)
# 10.12688/wellcomeopenres.14392.1 ('Q55153827', [], True)
# 10.1093/jmcb/mjy063 ('Q64447019', [], True)
# 10.7554/eLife.27574 ('Q42380836', [], True)
# 10.7554/eLife.27402 ('Q41664870', [], True)
# 10.7554/eLife.36530 ('Q56529918', [], True)
# 10.1074/mcp.RA118.000650 ('Q52648051', [], True)
# 10.15252/embr.201641983 ('Q42319174', [], True)
# 10.1038/s41586-018-0032-3 ('Q52719957', [], True)
# 10.7554/eLife.27356 ('Q47164119', [], True)
# 10.1016/j.cels.2017.06.009 ('Q53188680', [], True)
# 10.1074/jbc.M116.751024 ('Q39166548', [], True)
# 10.1016/j.cels.2016.06.011 ('Q28596873', [], True)
# 10.7554/eLife.04534 ('Q28650498', [], True)
# 10.1002/anie.201506019 ('Q51582435', [], True)
# 10.7554/eLife.01630 ('Q28658527', [], True)
# 10.1021/ac301652a ('Q34375189', [], True)
# 10.1074/mcp.M112.024547 ('Q39225646', [], True)
# 10.1007/s13361-011-0318-2 ('Q46103171', [], True)
# 10.1039/c1cp20784a ('Q33956981', [], True)
# 10.1021/ja1096804 ('Q46124692', [], True)
# 10.1039/c0cc03363d ('Q45934091', [], True)
# 10.1021/ja910665d ('Q34010129', [], True)
# 10.1021/pr800592t ('Q33396334', [], True)
# 10.1002/anie.200900613 ('Q33483433', [], True)
# 10.1002/rcm.4117 ('Q83974283', [], True)
# 10.1016/j.jasms.2009.02.009 ('Q46030857', [], True)
# 10.1021/ac800177s ('Q30369542', [], True)
# 10.1016/j.jasms.2008.07.006 ('Q30371293', [], True)
# 10.1021/ja076535a ('Q46559873', [], True)
# 10.1016/j.jasms.2006.05.007 ('Q30354904', [], True)
# 10.1021/ja067703m ('Q30052627', [], True)

# %% [markdown]
# # Federico Pelisch

# %%
create_or_get_wd(getDois("Federico Pelisch[AU]"))
# Out:
# 10.7554/eLife.65307 ('Q104563886', [], True)
# 10.1083/jcb.202011035 ('Q102204015', [], True)
# 10.1038/s41598-020-72637-9 ('Q99616863', [], True)
# 10.1242/jcs.232330 ('Q93051383', [], True)
# 10.1016/j.molcel.2016.11.001 ('Q37574622', [], True)
# 10.1007/978-1-4939-6358-4_17 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1038/ncomms7352 ('Q43180171', [], True)
# 10.1038/ncomms6485 ('Q30608755', [], True)
# 10.1073/pnas.1416858111 ('Q34480743', [], True)
# 10.4161/cc.26183 ('Q41846179', [], True)
# 10.1002/jcb.24103 ('Q37590130', [], True)
# 10.1093/bfgp/els053 ('Q38062297', [], True)
# 10.1002/iub.1075 ('Q38040017', [], True)
# 10.1074/jbc.M112.390120 ('Q39309267', [], True)
# 10.1002/jcb.22595 ('Q39690560', [], True)
# 10.1073/pnas.1004653107 ('Q34136544', [], True)
# 10.1016/j.cell.2009.03.010 ('Q39850003', [], True)
# 10.1002/jcb.22181 ('Q39851741', [], True)
# 10.1073/pnas.0810666106 ('Q37132771', [], True)
# 10.1016/j.biocel.2007.04.004 ('Q36824367', [], True)
# 10.1038/nsmb1020 ('Q64462274', [], True)
# 10.1074/jbc.M412007200 ('Q40424247', [], True)
# 10.1016/j.molcel.2005.06.035 ('Q40390684', [], True)
# 10.1074/jbc.M314260200 ('Q40577125', [], True)
# 10.1016/j.molcel.2003.08.001 ('Q40627617', [], True)

# %% [markdown]
# # Gordon G Simpson

# %%
create_or_get_wd(getDois("Gordon G Simpson[AU]"))
# Out:
# 10.1038/s41467-022-28753-3 ('Q111442295', [], True)
# 10.7554/eLife.65537 ('Q111442297', [], True)
# 10.1186/s13059-021-02296-0 ('Q111442298', [], True)
# 10.7554/eLife.49658 ('Q83224631', [], True)
# 10.1093/bioinformatics/btz089 (None, [], ValueError("More than one wikidata ID found for P236 1367-4803: [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4914910'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q27710219'}}]"))
# 10.1261/rna.058339.116 ('Q41131980', [], True)
# 10.1371/journal.pone.0160694 ('Q36101469', [], True)
# 10.1261/rna.053959.115 ('Q38889056', [], True)
# 10.1016/j.pbi.2015.05.015 ('Q26825716', [], True)
# 10.1186/s13059-015-0704-3 ('Q35827992', [], True)
# 10.1093/jxb/ert439 ('Q45761998', [], True)
# 10.1371/journal.pone.0094270 ('Q35145066', [], True)
# 10.1038/srep02866 ('Q42654766', [], True)
# 10.1126/science.1241602 ('Q43937171', [], True)
# 10.1371/journal.pgen.1003867 ('Q35034308', [], True)
# 10.1038/nsmb.2345 ('Q42442592', [], True)
# 10.1105/tpc.110.077990 ('Q42681796', [], True)
# 10.1042/BST0381077 ('Q37775673', [], True)
# 10.1016/j.devcel.2009.12.009 ('Q53348104', [], True)
# 10.1111/j.1365-313X.2009.03859.x ('Q47870963', [], True)
# 10.1242/dev.01924 ('Q53618149', [], True)
# 10.1002/bies.20201 ('Q36043790', [], True)
# 10.1387/ijdb.051995vq ('Q36227503', [], True)
# 10.1016/j.pbi.2004.07.002 ('Q35874413', [], True)
# 10.1093/emboj/cdg305 ('Q39777519', [], True)
# 10.1002/bies.10330 ('Q35206007', [], True)
# 10.1016/s0092-8674(03)00425-2 ('Q52104057', [], True)
# 10.1016/s1360-1385(02)02316-6 ('Q52114781', [], True)
# 10.1126/science.296.5566.285 ('Q33337109', [], True)

# %% [markdown]
# # Stéphane Pagès

# %%
create_or_get_wd(getDois("Stéphane Pagès[AU]"))
# Out:
# 10.1038/s41598-022-07445-4 ('Q111442023', [], True)
# 10.3389/fnsyn.2021.643138 ('Q111442026', [], True)
# 10.1073/pnas.2024920118 ('Q111442027', [], True)
# 10.1038/s41467-020-17005-x ('Q96765489', [], True)
# 10.1016/j.celrep.2019.12.019 ('Q92659576', [], True)
# 10.1038/s41592-019-0554-0 ('Q90135161', [], True)
# 10.1038/s41593-018-0093-5 ('Q88102934', [], True)
# 10.1523/JNEUROSCI.2430-15.2016 ('Q35906339', [], True)
# 10.3389/fnana.2015.00036 ('Q39326592', [], True)
# 10.3389/fnana.2015.00056 ('Q42560057', [], True)
# 10.1038/nature13664 ('Q43614842', [], True)
# 10.3389/fncel.2011.00020 ('Q34053245', [], True)
# 10.1371/journal.pone.0019928 ('Q27340360', [], True)
# 10.1021/jp0615252 ('Q83992165', [], True)
# 10.1021/jp0532216 ('Q50728942', [], True)
# 10.1021/ic0506512 ('Q80382459', [], True)
# 10.1063/1.1772362 ('Q45013394', [], True)

# %% [markdown]
# # Joerg Bewersdorf

# %%
create_or_get_wd(getDois("Joerg Bewersdorf[AU]"))
# Out:
# 10.1016/j.molcel.2022.02.025 ('Q111442036', [], True)
# 10.1016/j.cell.2021.05.008 ('Q111442037', [], True)
# 10.1364/AO.416585 ('Q111442038', [], True)
# 10.1038/s41592-021-01149-9 ('Q111442039', [], True)
# 10.1364/OPTICA.416841 ('Q111442040', [], True)
# 10.1021/acscentsci.1c00670 ('Q111442042', [], True)
# 10.1038/s41596-020-00428-7 ('Q111442045', [], True)
# 10.1016/j.bpj.2020.11.006 ('Q102216689', [], True)
# 10.1364/OL.397754 ('Q97416381', [], True)
# 10.1038/s41592-019-0676-4 ('Q92453890', [], True)
# 10.1038/s41467-020-17523-8 ('Q98184155', [], True)
# 10.1016/j.chembiol.2019.01.003 ('Q91466729', [], True)
# 10.1016/j.cell.2019.03.047 ('Q91769186', [], True)
# 10.1039/c8mh00644j ('Q93202536', [], True)
# 10.1083/jcb.201809107 ('Q60919736', [], True)
# 10.1038/s41592-018-0145-5 ('Q57059992', [], True)
# 10.1016/j.bpj.2018.07.028 ('Q91111775', [], True)
# 10.1073/pnas.1713845115 ('Q49790305', [], True)
# 10.1146/annurev-biochem-060815-014801 ('Q47224322', [], True)
# 10.1091/mbc.E16-07-0522 ('Q49515138', [], True)
# 10.1021/acs.biochem.7b00545 ('Q47814182', [], True)
# 10.1038/nbt.3876 ('Q38696851', [], True)
# 10.1364/OE.25.014049 ('Q53120415', [], True)
# 10.1091/mbc.E16-12-0863 ('Q41978971', [], True)
# 10.1073/pnas.1608252113 ('Q30819726', [], True)
# 10.1016/j.devcel.2016.08.002 ('Q39424289', [], True)
# 10.1364/OL.41.003631 ('Q41055357', [], True)
# 10.1016/j.cell.2016.06.016 ('Q37218547', [], True)
# 10.1002/1873-3468.12210 ('Q30778000', [], True)
# 10.1364/OE.24.008862 ('Q53114314', [], True)
# 10.1038/ncomms10778 ('Q27330209', [], True)
# 10.1007/978-1-4939-3145-3_4 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1096/fj.201500176 ('Q51546338', [], True)
# 10.1364/OL.40.004915 ('Q50279769', [], True)
# 10.1364/OL.40.003627 ('Q85885905', [], True)
# 10.1371/journal.pone.0128135 ('Q27305737', [], True)
# 10.1002/anie.201403349 ('Q36120993', [], True)
# 10.1242/jcs.143537 ('Q30586940', [], True)
# 10.1371/journal.pone.0114043 ('Q34600793', [], True)
# 10.1002/cm.21186 ('Q30587219', [], True)
# 10.1038/nmeth.2843 ('Q38191782', [], True)
# 10.1016/j.mcn.2014.07.006 ('Q28585799', [], True)
# 10.1038/ncb2940 ('Q42098117', [], True)
# 10.1364/OE.21.029462 ('Q35090506', [], True)
# 10.1038/nmeth.2488 ('Q30540988', [], True)
# 10.1039/c3cp51035b ('Q37284517', [], True)
# 10.1364/OL.38.001860 ('Q34748767', [], True)
# 10.1016/j.devcel.2013.01.013 ('Q30541918', [], True)
# 10.1017/S1431927612000268 ('Q43095363', [], True)
# 10.7554/eLife.00475 ('Q42437273', [], True)
# 10.1364/OE.20.020998 ('Q36793317', [], True)
# 10.1364/OL.37.001805 ('Q34290198', [], True)
# 10.1146/annurev-bioeng-071811-150025 ('Q36599552', [], True)
# 10.1364/OE.19.015009 ('Q51530416', [], True)
# 10.1364/OE.19.013351 ('Q33957713', [], True)
# 10.1364/BOE.2.002364 ('Q29399333', [], True)
# 10.1038/nmeth0211-132 ('Q83325735', [], True)
# 10.1021/nl1028792 ('Q33715664', [], True)
# 10.1016/j.bpj.2010.04.025 ('Q42731902', [], True)
# 10.1016/j.bbabio.2010.02.003 ('Q39741753', [], True)
# 10.1146/annurev-cellbio-100109-104048 ('Q37798552', [], True)
# 10.1242/jcs.052555 ('Q42579262', [], True)
# 10.1364/oe.17.008264 ('Q48852430', [], True)
# 10.1007/978-1-59745-483-4_32 (None, ['unknown type: book-chapter'], ValueError('can not create WDItemID with None'))
# 10.1016/j.bbabio.2008.04.002 ('Q39985951', [], True)
# 10.1038/nmeth.1211 ('Q33333439', [], True)
# 10.1007/s10577-008-1242-6 ('Q81228780', [], True)
# 10.1364/ol.32.003522 ('Q43134363', [], True)
# 10.1111/j.1460-9568.2007.05680.x ('Q33293606', [], True)
# 10.1007/s10577-007-1181-7 ('Q80149282', [], True)
